# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
highestgrosser = pd.read_csv('../HighestGrossers.csv')
ticketsales2 = pd.read_csv('../TicketSales_cleaned.csv')

# %%
highestgrosser.sort_values('YEAR', ascending=False)
# Out:
#     YEAR                                          MOVIE      GENRE  \
# 26  2021      Shang-Chi and the Legend of the Ten Rings        NaN
# 25  2020                              Bad Boys For Life        NaN
# 24  2019                              Avengers: Endgame        NaN
# 23  2018                                  Black Panther     Action
# 22  2017              Star Wars Ep. VIII: The Last Jedi     Action
# 21  2016                                   Finding Dory     Action
# 20  2015           Star Wars Ep. VII: The Force Awakens     Action
# 19  2014                        Guardians of the Galaxy  Adventure
# 18  2013                                     Iron Man 3  Adventure
# 17  2012                                   The Avengers  Adventure
# 16  2011  Harry Potter and the Deathly Hallows: Part II     Action
# 15  2010                                    Toy Story 3     Action
# 14  2009            Transformers: Revenge of the Fallen     Action
# ...

# %%
#combine ticket sales and highest grossingtables
HighestGrossingplussales = highestgrosser.merge(ticketsales2, how='inner', on='YEAR')
HighestGrossingplussales
# Out:
#     YEAR                                          MOVIE      GENRE  \
# 0   1995                                 Batman Forever      Drama
# 1   1996                               Independence Day  Adventure
# 2   1997                                   Men in Black  Adventure
# 3   1998                                        Titanic  Adventure
# 4   1999            Star Wars Ep. I: The Phantom Menace  Adventure
# 5   2000                 How the Grinch Stole Christmas  Adventure
# 6   2001          Harry Potter and the Sorcerer’s Stone  Adventure
# 7   2002                                     Spider-Man  Adventure
# 8   2003                                   Finding Nemo  Adventure
# 9   2004                                        Shrek 2  Adventure
# 10  2005         Star Wars Ep. III: Revenge of the Sith     Action
# 11  2006     Pirates of the Caribbean: Dead Man’s Chest     Action
# 12  2007                                   Spider-Man 3  Adventure
# ...

# %%
HighestGrossingplussales = HighestGrossingplussales.drop("Unnamed: 0", axis=1)

# %%
HighestGrossingplussales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 26
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   YEAR                                 27 non-null     int64
#  1   MOVIE                                27 non-null     object
#  2   GENRE                                24 non-null     object
#  3   MPAA RATING                          27 non-null     object
#  4   DISTRIBUTOR                          27 non-null     object
#  5   TOTAL FOR YEAR                       27 non-null     object
#  6   TOTAL IN 2019 DOLLARS                27 non-null     object
#  7   TICKETS SOLD_x                       27 non-null     object
#  8   TICKETS SOLD_y                       27 non-null     int64
#  9   TOTAL BOX OFFICE                     27 non-null     object
#  10  TOTAL INFLATION ADJUSTED BOX OFFICE  27 non-null     object
# ...

# %%
HighestGrossingplussales['GENRE'].value_counts()
# Out:
# Adventure    14
# Action        9
# Drama         1
# Name: GENRE, dtype: int64

# %%
HighestGrossingplussales['DISTRIBUTOR'].value_counts()
# Out:
# Walt Disney           12
# Sony Pictures          4
# Warner Bros.           4
# 20th Century Fox       3
# Paramount Pictures     2
# Dreamworks SKG         1
# Universal              1
# Name: DISTRIBUTOR, dtype: int64

# %%
HighestGrossingplussales['TICKETS SOLD_x'] = HighestGrossingplussales['TICKETS SOLD_x'].replace(',','', regex=True)
HighestGrossingplussales['TICKETS SOLD_x'] = HighestGrossingplussales['TICKETS SOLD_x'].astype('int64')

# %%
HighestGrossingplussales
# Out:
#     YEAR                                          MOVIE      GENRE  \
# 0   1995                                 Batman Forever      Drama
# 1   1996                               Independence Day  Adventure
# 2   1997                                   Men in Black  Adventure
# 3   1998                                        Titanic  Adventure
# 4   1999            Star Wars Ep. I: The Phantom Menace  Adventure
# 5   2000                 How the Grinch Stole Christmas  Adventure
# 6   2001          Harry Potter and the Sorcerer’s Stone  Adventure
# 7   2002                                     Spider-Man  Adventure
# 8   2003                                   Finding Nemo  Adventure
# 9   2004                                        Shrek 2  Adventure
# 10  2005         Star Wars Ep. III: Revenge of the Sith     Action
# 11  2006     Pirates of the Caribbean: Dead Man’s Chest     Action
# 12  2007                                   Spider-Man 3  Adventure
# ...

# %%
plt.figure(figsize=(30,5),dpi=300)
sns.lineplot(data=HighestGrossingplussales, y='MOVIE', x='TICKETS SOLD_x')
# plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=HighestGrossingplussales, y='MOVIE', x='TICKETS SOLD_x')
plt.xlabel('Tickets Sold in millions')
plt.show()

# %%
HighestGrossingplussales[['YEAR','MOVIE','TOTAL FOR YEAR','TICKETS SOLD_x','AVERAGE TICKET PRICE']]
# Out:
#     YEAR                                          MOVIE TOTAL FOR YEAR  \
# 0   1995                                 Batman Forever   $184,031,112
# 1   1996                               Independence Day   $306,169,255
# 2   1997                                   Men in Black   $250,650,052
# 3   1998                                        Titanic   $443,319,081
# 4   1999            Star Wars Ep. I: The Phantom Menace   $430,443,350
# 5   2000                 How the Grinch Stole Christmas   $253,367,455
# 6   2001          Harry Potter and the Sorcerer’s Stone   $300,404,434
# 7   2002                                     Spider-Man   $403,706,375
# 8   2003                                   Finding Nemo   $339,714,367
# 9   2004                                        Shrek 2   $441,226,247
# 10  2005         Star Wars Ep. III: Revenge of the Sith   $380,270,577
# 11  2006     Pirates of the Caribbean: Dead Man’s Chest   $423,315,812
# ...

# %%
HighestGrossingplussales[['YEAR','MOVIE','DISTRIBUTOR','TOTAL FOR YEAR','TICKETS SOLD_x']].sort_values('DISTRIBUTOR')
# Out:
#     YEAR                                          MOVIE         DISTRIBUTOR  \
# 1   1996                               Independence Day    20th Century Fox
# 4   1999            Star Wars Ep. I: The Phantom Menace    20th Century Fox
# 10  2005         Star Wars Ep. III: Revenge of the Sith    20th Century Fox
# 9   2004                                        Shrek 2      Dreamworks SKG
# 3   1998                                        Titanic  Paramount Pictures
# 14  2009            Transformers: Revenge of the Fallen  Paramount Pictures
# 2   1997                                   Men in Black       Sony Pictures
# 7   2002                                     Spider-Man       Sony Pictures
# 12  2007                                   Spider-Man 3       Sony Pictures
# 25  2020                              Bad Boys For Life       Sony Pictures
# 5   2000                 How the Grinch Stole Christmas           Universal
# ...

# %%
pieplot = HighestGrossingplussales[['DISTRIBUTOR', 'TOTAL FOR YEAR']]
sns.catplot(data=HighestGrossingplussales, x='GENRE', y='TOTAL FOR YEAR')

# %%
sns.barplot(data=HighestGrossingplussales, x='GENRE', y='TOTAL FOR YEAR')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-878489603ab6> in <module>
# ----> 1 sns.barplot(data=HighestGrossingplussales, x='GENRE', y='TOTAL FOR YEAR')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3180                           estimator, ci, n_boot, units, seed,
# ...
