# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ticketsales = pd.read_csv('../AnnualTicketSales.csv')

# %%
ticketsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   YEAR                                 27 non-null     int64
#  1   TICKETS SOLD                         27 non-null     object
#  2   TOTAL BOX OFFICE                     27 non-null     object
#  3   TOTAL INFLATION ADJUSTED BOX OFFICE  27 non-null     object
#  4   AVERAGE TICKET PRICE                 27 non-null     object
#  5   Unnamed: 5                           0 non-null      float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.4+ KB

# %%
ticketsales['TICKETS SOLD'] = ticketsales['TICKETS SOLD'].replace(',','', regex=True)

# %%
ticketsales['TICKETS SOLD'] = ticketsales['TICKETS SOLD'].astype('int64')

# %%
ticketsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   YEAR                                 27 non-null     int64
#  1   TICKETS SOLD                         27 non-null     int64
#  2   TOTAL BOX OFFICE                     27 non-null     object
#  3   TOTAL INFLATION ADJUSTED BOX OFFICE  27 non-null     object
#  4   AVERAGE TICKET PRICE                 27 non-null     object
#  5   Unnamed: 5                           0 non-null      float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.4+ KB

# %%
ticketsales
# Out:
#     YEAR  TICKETS SOLD TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# 0   2021     423774881   $3,881,777,912                      $3,881,777,912
# 1   2020     223638958   $2,048,534,616                      $2,048,534,616
# 2   2019    1228541629  $11,253,443,955                     $11,253,444,050
# 3   2018    1311536128  $11,948,096,650                     $12,013,670,952
# 4   2017    1225639761  $10,993,991,460                     $11,226,860,216
# 5   2016    1302556378  $11,267,115,924                     $11,931,416,424
# 6   2015    1323356776  $11,155,900,636                     $12,121,948,075
# 7   2014    1257402920  $10,272,985,008                     $11,517,810,744
# 8   2013    1339168926  $10,887,446,341                     $12,266,787,382
# 9   2012    1380921942  $10,992,141,616                     $12,649,244,986
# 10  2011    1282915168  $10,173,519,704                     $11,751,502,955
# ...

# %%
ticketsales['Total Box Office Numeric'] = ticketsales['TOTAL BOX OFFICE'].values
ticketsales['Total Box Office Numeric'] = ticketsales['Total Box Office Numeric'].replace('\$','', regex=True)
ticketsales['Total Box Office Numeric'] = ticketsales['Total Box Office Numeric'].replace(' ','', regex=True)
ticketsales['Total Box Office Numeric'] = ticketsales['Total Box Office Numeric'].replace(',','', regex=True)

# %%
ticketsales['Total Box Office Numeric'] = ticketsales['Total Box Office Numeric'].replace('\$','', regex=True)

# %%
ticketsales['Total Box Office Numeric'] = ticketsales['Total Box Office Numeric'].replace(' ','', regex=True)

# %%
ticketsales['Total Box Office Numeric'] = ticketsales['Total Box Office Numeric'].replace(',','', regex=True)

# %%
ticketsales
# Out:
#     YEAR  TICKETS SOLD TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# 0   2021     423774881   $3,881,777,912                      $3,881,777,912
# 1   2020     223638958   $2,048,534,616                      $2,048,534,616
# 2   2019    1228541629  $11,253,443,955                     $11,253,444,050
# 3   2018    1311536128  $11,948,096,650                     $12,013,670,952
# 4   2017    1225639761  $10,993,991,460                     $11,226,860,216
# 5   2016    1302556378  $11,267,115,924                     $11,931,416,424
# 6   2015    1323356776  $11,155,900,636                     $12,121,948,075
# 7   2014    1257402920  $10,272,985,008                     $11,517,810,744
# 8   2013    1339168926  $10,887,446,341                     $12,266,787,382
# 9   2012    1380921942  $10,992,141,616                     $12,649,244,986
# 10  2011    1282915168  $10,173,519,704                     $11,751,502,955
# ...

# %%
ticketsales['Total Box Office Numeric'] = ticketsales['Total Box Office Numeric'].astype('int64')

# %%
ticketsales['Total Box Office Numeric'] = ticketsales['TOTAL BOX OFFICE'].values

# %%
ticketsales = ticketsales.drop("Unnamed: 5", axis=1)
ticketsales = ticketsales.drop("Copied_Column", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-f969b6e5d0f7> in <module>
#       1 ticketsales = ticketsales.drop("Unnamed: 5", axis=1)
# ----> 2 ticketsales = ticketsales.drop("Copied_Column", axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
ticketsales2 = ticketsales

# %%
ticketsales2['TOTAL BOX OFFICE'] = ticketsales2['TOTAL BOX OFFICE'].replace('\$','', regex=True)
ticketsales2['TOTAL BOX OFFICE'] = ticketsales2['TOTAL BOX OFFICE'].replace(',','', regex=True)
ticketsales2['TOTAL INFLATION ADJUSTED BOX OFFICE'] = ticketsales2['TOTAL INFLATION ADJUSTED BOX OFFICE'].replace(',','', regex=True)
ticketsales2['TOTAL INFLATION ADJUSTED BOX OFFICE'] = ticketsales2['TOTAL INFLATION ADJUSTED BOX OFFICE'].replace('$','', regex=True)

# %%
ticketsales2['TOTAL INFLATION ADJUSTED BOX OFFICE'] = ticketsales2['TOTAL INFLATION ADJUSTED BOX OFFICE'].replace('\$','', regex=True)

# %%
ticketsales2['Total Box Office Numeric'] = ticketsales2['Total Box Office Numeric'].replace('\$','', regex=True)

# %%
ticketsales2['AVERAGE TICKET PRICE'] = ticketsales2['AVERAGE TICKET PRICE'].replace('\$','', regex=True)

# %%
ticketsales2['Total Box Office Numeric'] = ticketsales2['Total Box Office Numeric'].replace(',','', regex=True)

# %%
ticketsales2
# Out:
#     YEAR  TICKETS SOLD TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# 0   2021     423774881       3881777912                          3881777912
# 1   2020     223638958       2048534616                          2048534616
# 2   2019    1228541629      11253443955                         11253444050
# 3   2018    1311536128      11948096650                         12013670952
# 4   2017    1225639761      10993991460                         11226860216
# 5   2016    1302556378      11267115924                         11931416424
# 6   2015    1323356776      11155900636                         12121948075
# 7   2014    1257402920      10272985008                         11517810744
# 8   2013    1339168926      10887446341                         12266787382
# 9   2012    1380921942      10992141616                         12649244986
# 10  2011    1282915168      10173519704                         11751502955
# ...

# %%
ticketsales2.to_csv('../TicketSales_cleaned.csv')

# %%
plt.figure(figsize=(26,5), dpi=300)
sns.catplot(data=ticketsales, y='AVERAGE TICKET PRICE', x= 'YEAR')
plt.title('')
plt.show()

# %%
plt.figure(figsize=(26,5), dpi=300)
sns.lineplot(data=ticketsales, y='AVERAGE TICKET PRICE', x= 'YEAR')

# %%
Amountmade = ticketsales[['YEAR','TICKETS SOLD','Total Box Office Numeric']]

# %%
plt.figure(figsize=(26,5), dpi=300)
sns.barplot(data=Amountmade, x='YEAR', y='Total Box Office Numeric')
plt.xlabel('YEAR')
plt.ylabel('Total Box Office in Millions')
plt.show()

# %%
ticketsales.mean()
